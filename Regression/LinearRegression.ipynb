# %% [markdown]
# ## Linear Regression Using Python

# %% [markdown]
# #### Problem Statement
# Given the dataset of advertisign Predict sales based of TV ads

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %% [markdown]
# ### Dataset
# The dataset contains various advertising medias and their respective sales
# - **TV**:Advertising in TV
# - **radio**:Advertising in radio
# - **newspaper**:Advertising in newspaper

# %%
# Reading from csv file
data = pd.read_csv('Advertising.csv')
data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
# Plotting sales vs TV ads
plt.figure()
plt.scatter(data['TV'], data['sales'], c='black')
plt.xlabel("TV ads")
plt.ylabel("Sales")
plt.show()

# %%
# Reshaping and fitting the data into simple linear regression

X = data['TV'].values.reshape(-1,1)
y = data['sales'].values.reshape(-1,1)
reg = LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# #### R-squared Value

# %%
reg.score(X,y)
# Out:
# 0.611875050850071

# %%
# Print coefficient and intercept
print(reg.coef_)
print(reg.intercept_)
# Out:
# [[0.04753664]]
# [7.03259355]

# %% [markdown]
# ### Plotting actual vs predicted values

# %%
y_pred = reg.predict(X)
plt.figure()
plt.scatter(data['TV'], data['sales'], c='yellow')
plt.plot(data['TV'], y_pred, c='blue', linewidth=2)
plt.xlabel("TV ads")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# ### Statistical model

# %%
X = data['TV']
y = data['sales']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):           1.47e-42
# Time:                        16:15:19   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.0326      0.458     15.360      0.000       6.130       7.935
# ...
